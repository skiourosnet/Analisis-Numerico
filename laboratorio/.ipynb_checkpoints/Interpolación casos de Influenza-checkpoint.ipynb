# %% [markdown]
# # Interpolación series de tiempo de casos de influenza

# %%
# Importamos librerias
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline, interp1d, PchipInterpolator, make_interp_spline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
influenza_seasons = pd.read_csv("influenza_seasons_clean.csv")
influenza_seasons .head()
# Out:
#    TEMPORADA FECHA_SINTOMAS  YEAR_EPI  SEMANA_EPI CONFIRMADO_FLU  \
# 0  2024-2025     2024-09-01      2024          36             SI
# 1  2024-2025     2024-09-01      2024          36             SI
# 2  2024-2025     2024-09-01      2024          36             SI
# 3  2024-2025     2024-09-01      2024          36             SI
# 4  2024-2025     2024-09-01      2024          36             SI
#
#                SECTOR SEMANA_CALENDARIO  SEMANA_RELATIVA  GRUPO_EDAD  \
# 0                 SSA         2024-SE36                1    0-4 años
# 1  IMSS Bienestar OPD         2024-SE36                1   5-19 años
# 2                 SSA         2024-SE36                1  20-64 años
# 3              ISSSTE         2024-SE36                1   5-19 años
# 4                 SSA         2024-SE36                1  20-64 años
#
#     ENTIDAD_RES  CVE_ENTIDAD
# 0       YUCATÁN           31
# 1  QUINTANA ROO           23
# 2       YUCATÁN           31
# 3      GUERRERO           12
# 4       YUCATÁN           31

# %% [markdown]
# Contamos el número de casos por semana

# %%
# Agrupamos por Temporada y Semana Relativa
weekly_counts = (
    influenza_seasons
    .groupby(['TEMPORADA', 'SEMANA_RELATIVA'])
    .size()
    .reset_index(name='CASOS')
)
weekly_counts
# Out:
#     TEMPORADA  SEMANA_RELATIVA  CASOS
# 0   2024-2025                1    134
# 1   2024-2025                2    145
# 2   2024-2025                3    162
# 3   2024-2025                4    125
# 4   2024-2025                5    102
# ..        ...              ...    ...
# 76  2025-2026               29    224
# 77  2025-2026               30    187
# 78  2025-2026               31    106
# 79  2025-2026               32     39
# 80  2025-2026               33      1
#
# [81 rows x 3 columns]

# %%
# Esto creará una línea por cada temporada sobre el mismo eje X (semanas)
sns.relplot(
    data=weekly_counts, 
    x='SEMANA_RELATIVA', 
    y='CASOS', 
    hue='TEMPORADA', 
    kind='line', 
    height=5, 
    aspect=2
)
plt.title('Curvas Epidémicas por Temporada')
plt.show()

# %%
weekly_countsT1 = weekly_counts[weekly_counts['TEMPORADA']=='2024-2025']
weekly_countsT1.head()
# Out:
#    TEMPORADA  SEMANA_RELATIVA  CASOS
# 0  2024-2025                1    134
# 1  2024-2025                2    145
# 2  2024-2025                3    162
# 3  2024-2025                4    125
# 4  2024-2025                5    102

# %%
L = len(weekly_countsT1)
SemanasReporte = np.array([weekly_countsT1['SEMANA_RELATIVA'][i] for i in range(L)])
InfeccionesReportadas = np.array([weekly_countsT1['CASOS'][i] for i in range(L)])

SemanasNoReporte = [i for i in range(1,53) if i not in SemanasReporte]

# %%
pchip = PchipInterpolator(SemanasReporte, Infecciones)
X = np.linspace(1, 52, 3*104)
Y = pchip(X)

InfeccionPrediccion = pchip(SemanasNoReporte)

# %%
plt.figure(figsize=(10,6))
plt.plot(X, Y, label='Cubic Spline', color='blue')
plt.plot(SemanasReporte, Infecciones, 'ro', label='Datos originales')
plt.plot(SemanasNoReporte, InfeccionPrediccion, 'ko', label='Semanas no reportadas')
plt.title("Interpolación casos de influenza temporada 2024-2025")
plt.grid(True)
plt.legend()
plt.show()

# %%
interpoladores = [CubicSpline, PchipInterpolator, interp1d]

plt.figure(figsize=(12,6))
for f in interpoladores:
    p = f(SemanasReporte, Infecciones)
    X = np.linspace(1, 52, 7*52)
    Y = p(X)
    InfeccionPrediccion = p(SemanasNoReporte)
    plt.plot(X, Y, label=f.__name__)

plt.plot(SemanasReporte, Infecciones, 'ko', label='Datos originales')
plt.title("Interpolación casos de influenza temporada 2024-2025")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Modelos GLM

# %%
Influenza = np.array([[SemanasReporte[i], InfeccionesReportadas[i]] for i in range(SemanasReporte.size)])
Xglm = Influenza[:, 0]
Xglm = sm.add_constant(Xglm)

yglm = Influenza[:, 1]

# %%
test = np.array([1,16]).reshape(1,-1)
InfeccionPrediccionGLM = results.predict(test)
InfeccionPrediccionGLM
# Out:
# array([525.29579595])

# %%
model = sm.GLM(yglm, Xglm, family=sm.families.Gaussian())

# %%
results=model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:                            GLM   Df Residuals:                       46
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                      2.5127e+05
# Method:                          IRLS   Log-Likelihood:                -365.51
# Date:                Wed, 22 Apr 2026   Deviance:                   1.1559e+07
# Time:                        14:16:36   Pearson chi2:                 1.16e+07
# No. Iterations:                     3   Pseudo R-squ. (CS):           0.005036
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        559.1702    148.739      3.759      0.000     267.646     850.694
# x1            -2.1172      4.740     -0.447      0.655     -11.407       7.173
# ==============================================================================

# %%
plt.figure(figsize=(10,6))
plt.plot(X, Y, label='Cubic Spline', color='blue')
plt.plot(SemanasReporte, Infecciones, 'ro', label='Datos originales')
plt.plot(SemanasNoReporte, InfeccionPrediccion, 'ko', label='Semanas no reportadas')
plt.title("Interpolación casos de influenza temporada 2024-2025")
plt.grid(True)
plt.legend()
plt.show()
